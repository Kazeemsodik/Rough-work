# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from scipy.stats import kurtosis,skew
import seaborn as sns
#import pingouin as pg
df = pd.read_csv("downloaded.csv")
downloaded=df
for dfs in df:
    print(dfs)
# Out:
# record_id
# utility_id_ferc1
# report_year
# plant_name_ferc1
# fuel_type_code_pudl
# fuel_unit
# fuel_qty_burned
# fuel_mmbtu_per_unit
# fuel_cost_per_unit_burned
# fuel_cost_per_unit_delivered
# fuel_cost_per_mmbtu

# %%
fuel_cost_per_unit_burneds = df['fuel_cost_per_unit_burned']
for fuel_cost_per_unit_burn in fuel_cost_per_unit_burneds:
    print(fuel_cost_per_unit_burn)
# Out:
# 18.59
# 18.58
# 39.72
# 47.21
# 2.77
# 44.24
# 28.77
# 58.54
# 33.97
# 28.73
# 1.94
# 28.71
# 1.94
# 30.248
# 32.13
# 44.403999999999996
# 44.312
# 36.268
# 46.023999999999994
# 33.321
# 39.911
# 30.319000000000003
# 39.85
# 32.184
# 40.144
# 32.186
# 31.52
# 32.65
# 2.49
# 21.17
# 2.69
# 21.99
# 2.98
# 2.18
# 33.7
# 2.21
# 39.14
# 2.38
# 24.02
# 2.3
# 39.88
# 2.54
# 2.21
# 53.71
# 1.93
# 40803.0
# 30.41
# 2.29
# 44.92
# 34.18
# 49.35
# 3.86
# 44.0
# 41.31
# 37.51
# 37.29
# 31.44
# 3.29
# 38.87
# 3.86
# 31.68
# 37.77
# 35.58
# 35.81
# 36.65
# 2.92
# 41.93
# 3.55
# 35.82
# 38.07
# 40.56
# 33.04
# 2.84
# 4.82
# 2.79
# 2.92
# 29.07
# 42.18
# 2.75
# 39.97
# 2.89
# 37.29
# 32.15
# 3.29
# 14.685
# 2.09
# 18.37
# 29.29
# 3.173
# 14.72
# 10.1
# 2.371
# 28.415
# 54.121
# 48.16
# 42.99
# 2.94
# 49.71
# 41.34
# 50.37
# 3.77
# 32.98
# 44.24
# 40.89
# 46.73
# 38.96
# 40.22
# 3.63
# 31.0
# 34.22
# 41.115
# 38.436
# 4.188
# 2.2969999999999997
# 36.236
# 1.868
# 2.6710000000000003
# 2.227
# 41.707
# ...

# %%
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
(fuel_cost_per_unit_burneds, fuel_type_code_pudls) = df['fuel_cost_per_unit_burned','fuel_type_code_pudl']
for fuel_cost_per_unit_burn,fuel_type in (fuel_cost_per_unit_burneds,fuel_type_code_pudls):
    print(fuel_cost_per_unit_burn,fuel_type)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6fcf9dfbd479> in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
downloaded
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
dataframe = pd.read_csv('downloaded.csv')
x = dataframe.fuel_type_code_pudl
y = dataframe.fuel_cost_per_unit_burned
plt.scatter(x,y)
plt.show()

# %%
fuel_qty_burneds = df['fuel_qty_burned']
fuel_qty_burneds.skew()
# Out:
# 15.851495469109503

# %%
fuel_qty_burneds = df['fuel_qty_burned']
fuel_qty_burneds.kurt()
# Out:
# 651.3694501337732

# %%
pg.corr(x=df['fuel_cost_per_unit_burned'], y=df['dfs'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b646acbea9b0> in <module>
# ----> 1 pg.corr(x=df['fuel_cost_per_unit_burned'], y=df['dfs'])
#
# NameError: name 'pg' is not defined

# %%
fuel_cost_per_unit_burneds = df['fuel_cost_per_unit_burned']
corrs=df.corr()
mask=np.zeros_like(corrs)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(corrs, cmap='Spectral_r', mask=mask, square=True, vmin=-.4, vmax=.4)
plt.title('Correlation matrix')
# Out:
# Text(0.5, 1, 'Correlation matrix')

# %%
fuel_mmbtu_per_units=df['fuel_mmbtu_per_unit']
SD=np.std(fuel_mmbtu_per_units)
quartile75=np.percentile(fuel_mmbtu_per_units,[75])
print(SD)
print(quartile75)
# Out:
# 10.600040781504145
# [17.006]

# %%
dataframe = pd.read_csv('downloaded.csv')
report_years=df['report_year']
x = dataframe.fuel_type_code_pudls
z = dataframe.report_years
plt.hist(x,z)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-f9ed7fa397db> in <module>
#       2 x = dataframe.fuel_type_code_pudl
#       3 z = dataframe.report_year
# ----> 4 plt.hist(x,z)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...

# %%
value=['coal']
coal=df[df.fuel_type_code_pudl.isin(value)]
print(coal)
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# ...                         ...               ...          ...
# 29503  f1_fuel_2018_12_191_1_14               191         2018
# 29510   f1_fuel_2018_12_403_0_2               403         2018
# 29516    f1_fuel_2018_12_12_0_8                12         2018
# 29517   f1_fuel_2018_12_12_0_10                12         2018
# 29521   f1_fuel_2018_12_12_1_13                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
dataframe = pd.read_csv('downloaded.csv')
x = dataframe.coal
z = dataframe.report_year
plt.hist(x,z)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-b68afeed62cd> in <module>
#       1 dataframe = pd.read_csv('downloaded.csv')
# ----> 2 x = dataframe.coal
#       3 z = dataframe.report_year
#       4 plt.hist(x,z)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'coal'

# %%
for coals in coal:
    print(coal)
x = sorted(dataframe.report_year)
y = sorted(dataframe.fuel_type_code_pudl)
plt.hist(x,y)
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# ...                         ...               ...          ...
# 29503  f1_fuel_2018_12_191_1_14               191         2018
# 29510   f1_fuel_2018_12_403_0_2               403         2018
# 29516    f1_fuel_2018_12_12_0_8                12         2018
# 29517   f1_fuel_2018_12_12_0_10                12         2018
# 29521   f1_fuel_2018_12_12_1_13                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
plt.hist(coal,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-8b8d65654f9e> in <module>
# ----> 1 plt.hist(coal,5)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2641         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2642         color=color, label=label, stacked=stacked, normed=normed,
# -> 2643         **({"data": data} if data is not None else {}), **kwargs)
#    2644
#    2645
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
# ...

# %%
dataframe = pd.read_csv('downloaded.csv')
report_years=df['report_year']
fuel_type_code_pudls = df['fuel_type_code_pudl']
x = dataframe.fuel_type_code_pudls
z = dataframe.report_years
plt.hist(x,z)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-0fae378a0261> in <module>
#       2 report_years=df['report_year']
#       3 fuel_type_code_pudls = df['fuel_type_code_pudl']
# ----> 4 x = dataframe.fuel_type_code_pudls
#       5 z = dataframe.report_years
#       6 plt.hist(x,z)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'fuel_type_code_pudls'

# %%
dataframe = pd.read_csv('downloaded.csv')
x = dataframe.fuel_type_code_pudl
y = dataframe.report_year
plt.scatter(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-38b49fd20710> in <module>
#       1 dataframe = pd.read_csv('downloaded.csv')
# ----> 2 x = dataframe.fuel_type_code_pudl.coal
#       3 y = dataframe.report_year
#       4 plt.scatter(x,y)
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'coal'

# %%
dataframe = pd.read_csv('downloaded.csv')
x = dataframe.report_year
y = dataframe.fuel_cost_per_unit_delivered
plt.pie(x,y)
plt.show()

# %%
dataframe = pd.read_csv('downloaded.csv')
x = dataframe.report_year
y = dataframe.fuel_cost_per_unit_delivered
plt.bar(x,y)
plt.show()

# %%
dataframe = pd.read_csv('downloaded.csv')
x = dataframe.report_year
y = dataframe.fuel_cost_per_unit_delivered
plt.scatter(x,y)

# %%
dataframe = pd.read_csv('downloaded.csv')
x = dataframe.report_year
y = dataframe.fuel_cost_per_unit_burned
plt.scatter(x,y)

# %%
sum(1994)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-e24050d60986> in <module>
# ----> 1 sum(1994)
#
# TypeError: 'int' object is not iterable
